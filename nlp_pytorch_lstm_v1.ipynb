# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshippili/pytorch_stuff/blob/main/nlp_pytorch_lstm_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip mydata.zip
# Out:
# Archive:  mydata.zip
#    creating: mydata/
#   inflating: mydata/val.csv
#   inflating: mydata/train.csv
#   inflating: mydata/test.csv

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.legacy.data import Field, BucketIterator,TabularDataset

import spacy
import numpy as np

import random
import math
import time

# %%
# import pandas as pd
# df = pd.read_csv("/content/mydata/train.csv")

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
spacy_en = spacy.load('en')

# %%
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings (tokens)
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
SRC = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

TRG = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

# %%
feilds = [('text', SRC), ('summary', TRG)]

# %%
train_data,val_data = TabularDataset.splits(
    path="/content/mydata", format='csv',
    train="train.csv",
    validation="val.csv",
    fields=feilds
)

# %%
# for batch in train_iterator:
#   for e in batch:
#     print(e[0])
#     print(e[1])
#     break
#   break

# %%
SRC.build_vocab(train_data, max_size=10000, min_freq=3)
TRG.build_vocab(train_data, max_size=10000, min_freq=3)

# %%
print(f"Unique tokens in source (de) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (en) vocabulary: {len(TRG.vocab)}")
# Out:
# Unique tokens in source (de) vocabulary: 8325
# Unique tokens in target (en) vocabulary: 2683

# %%
print(SRC.vocab.__dict__.keys())
print(list(SRC.vocab.__dict__.values()))
e = list(SRC.vocab.__dict__.values())
for i in e:
  print(i)
# Out:
# dict_keys(['freqs', 'itos', 'unk_index', 'stoi', 'vectors'])
# [Counter({'great': 7477, 'good': 7196, 'like': 6477, 'love': 5347, 'taste': 5088, 'product': 5087, 'coffee': 4520, 'flavor': 4419, 'one': 4004, 'tea': 3735, 'would': 3571, 'best': 3014, 'price': 2988, 'really': 2896, 'get': 2731, 'buy': 2703, 'amazon': 2608, 'much': 2422, 'find': 2314, 'time': 2230, 'use': 2125, 'better': 2098, 'little': 2063, 'tried': 2031, 'food': 1988, 'well': 1791, 'eat': 1789, 'dog': 1775, 'make': 1745, 'delicious': 1719, 'chocolate': 1716, 'loves': 1704, 'also': 1645, 'try': 1637, 'bought': 1632, 'order': 1611, 'favorite': 1555, 'even': 1528, 'recommend': 1519, 'tastes': 1491, 'can': 1433, 'not': 1433, 'sweet': 1414, 'found': 1413, 'cup': 1380, 'store': 1318, 'could': 1309, 'nice': 1305, 'free': 1303, 'drink': 1300, 'used': 1288, 'bag': 1271, 'sugar': 1259, 'perfect': 1232, 'dogs': 1216, 'way': 1204, 'go': 1182, 'ordered': 1180, 'easy': 1160, 'got': 1147, 'ever': 1145, 'made': 1144, 'snack': 1130, 'box': 1097, 'first': 1087, 'makes': 1054, 'day': 1048, 'stuff': 1036, 'quality': 1031, 'treats': 1027, 'every': 1019, 'hot': 1015, 'flavors': 1009, 'excellent': 1004, 'mix': 1002, 'right': 1001, 'tasty': 1000, 'think': 987, 'healthy': 979, 'many': 970, 'hard': 966, 'fresh': 963, 'definitely': 958, 'always': 951, 'wonderful': 947, 'never': 937, 'keep': 930, 'bit': 928, 'strong': 926, 'chips': 919, 'since': 918, 'give': 916, 'water': 914, 'buying': 913, 'happy': 912, 'know': 910, 'without': 904, 'brand': 886, 'highly': 886, 'enjoy': 875, 'treat': 874, 'purchase': 871, 'still': 864, 'two': 861, 'stores': 858, 'old': 835, 'want': 831, '
 492, 'thanks': 487, 'fruit': 486, 'several': 485, 'getting': 483, 'calories': 483, 'works': 480, 'people': 479, 'gift': 476, 'ones': 474, 'coconut': 473, 'nt': 472, 'natural': 472, 'bar': 472, 'around': 471, 'glad': 471, 'light': 470, 'home': 467, 'another': 465, 'quickly': 465, 'smell': 461, 'away': 461, 'cheese': 461, 'cheaper': 457, 'liked': 450, 'yummy': 450, 'flavored': 445, 'son': 444, 'especially': 439, 'half': 437, 'available': 437, 'kind': 433, 'house': 429, 'bread': 428, 'cats': 427, 'diet': 427, 'save': 426, 'case': 426, 'us': 426, 'trying': 425, 'teeth': 423, 'nothing': 422, 'come': 421, 'days': 420, 'variety': 419, 'recommended': 419, 'amazing': 418, 'usually': 408, 'spicy': 408, 'seems': 407, 'per': 404, 'added': 401, 'thank': 401, 'fat': 401, 'others': 401, 'awesome': 400, 'company': 399, 'everyone': 399, 'packaging': 398, 'rich': 397, 'black': 394, 'boxes': 394, 'everything': 393, 'problem': 392, 'oz': 390, 'large': 388, 'daughter': 388, 'value': 384, 'ho ...
# ['<unk>', '<pad>', '<sos>', '<eos>', 'great', 'good', 'like', 'love', 'taste', 'product', 'coffee', 'flavor', 'one', 'tea', 'would', 'best', 'price', 'really', 'get', 'buy', 'amazon', 'much', 'find', 'time', 'use', 'better', 'little', 'tried', 'food', 'well', 'eat', 'dog', 'make', 'delicious', 'chocolate', 'loves', 'also', 'try', 'bought', 'order', 'favorite', 'even', 'recommend', 'tastes', 'can', 'not', 'sweet', 'found', 'cup', 'store', 'could', 'nice', 'free', 'drink', 'used', 'bag', 'sugar', 'perfect', 'dogs', 'way', 'go', 'ordered', 'easy', 'got', 'ever', 'made', 'snack', 'box', 'first', 'makes', 'day', 'stuff', 'quality', 'treats', 'every', 'hot', 'flavors', 'excellent', 'mix', 'right', 'tasty', 'think', 'healthy', 'many', 'hard', 'fresh', 'definitely', 'always', 'wonderful', 'never', 'keep', 'bit', 'strong', 'chips', 'since', 'give', 'water', 'buying', 'happy', 'know', 'without', 'brand', 'highly', 'enjoy', 'treat', 'purchase', 'still', 'two', 'stores', 'old', 'want', 'lot', 'small', 'local', 'tasting', 'years', 'shipping', 'tasted', 'say', 'size', 'bad', 'arrived', 'less', 'loved', 'far', 'salt', 'different', 'need', 'enough', 'add', 'cups', 'worth', 'long', 'something', 'organic', 'however', 'purchased', 'looking', 'cookies', 'pack', 'gluten', 'regular', 'candy', 'eating', 'received', 'though', 'bags', 'sure', 'thought', 'item', 'family', 'pretty', 'back', 'bars', 'milk', 'whole', 'popcorn', 'low', 'work', 'put', 'products', 'green', 'using', 'high', 'texture', 'came', 'package', 'fast', 'grocery', 'sauce', 'blend', 'expensive', 'kids', 'money', 'quite', 'big', 'year', 'last', 'morning', 'anything', 'thing', 'disappointed', 'husband', 'real', 'wish', 'absolutely', 'full', 'going', 'cereal', 'rice', 'ingredients', 'take', 'almost', 'cat', 'feel', 'oil', 'dark', 'bitter', 'deal', 'amount', 'breakfast', 'new', 'quick', 'smooth', 'ordering', 'able', 'butter', 'brands', 'actually', 'see', 'chicken', 'thanks', 'fruit', 'several', 'calories', 'getting', 'works', 'people', 'gift', 'ones', 'coconut', 'bar', 'natural', 'nt', 'around', 'glad', 'light', 'home', 'another', 'quickly', 'away', 'cheese', 'smell', 'cheaper', 'liked', 'yummy', 'flavored', 'son', 'especially', 'available', 'half', 'kind', 'house', 'bread', 'cats', 'diet', 'case', 'save', 'us', 'trying', 'teeth', 'nothing', 'come', 'days', 'recommended', 'variety', 'amazing', 'spicy', 'usually', 'seems', 'per', 'added', 'fat', 'others', 'thank', 'awesome', 'company', 'everyone', 'packaging', 'rich', 'black', 'boxes', 'everything', 'problem', 'oz', 'daughter', 'large', 'honey', 'value', 'fine', 'likes', 'syrup', 'pasta', 'must', 'said', 'peanut', 'foods', 'instead', 'times', 'anyone', 'making', 'prefer', 'cost', 'enjoyed', 'delivery', 'month', 'months', 'teas', 'comes', 'plus', 'protein', 'white', 'may', 'probably', 'super', 'look', 'nuts', 'fan', 'roast', 'things', 'dry', 'service', 'three', 'vanilla', 'gave', 'keurig', 'pleased', 'bottle', 'seem', 'salty', 'bold', 'crunchy', 'expected', 'cans', 'friends', 'soup', 'extra', 'soft', 'meal', 'energy', 'yet', 'wanted', 'fact', 'drinking', 'ok', 'baby', 'juice', 'reviews', 'cream', 'else', 'top', 'flavorful', 'longer', 'jerky', 'online', 'pieces', 'maybe', 'snacks', 'ice', 'chew', 'help', 'next', 'stars', 'wife', 'exactly', 'either', 'shipped', 'crackers', 'market', 'open', 'says', 'beans', 'beef', 'decaf', 'health', 'cold', 'might', 'lemon', 'cinnamon', 'alternative', 'packaged', 'second', 'went', 'plastic', 'convenient', 'corn', 'couple', 'least', 'fantastic', 'ginger', 'bulk', 'goes', 'noodles', 'cookie', 'mouth', 'continue', 'cooking', 'cocoa', 'dried', 'special', 'wheat', 'although', 'christmas', 'french', 'weight', 'believe', 'machine', 'refreshing', 'run', 'took', 'week', 'clean', 'place', 'care', 'delivered', 'sent', 'version', 'mild', 'pepper', 'smells', 'friend', 'ago', 'plain', 'soda', 'chewy', 'seeds', 'subscribe', 'cake', 'rather', 'aroma', 'drinks', 'gets', 'let', 'wrong', 'aftertaste', 'coffees', 'smaller', 'spi ...
# 0
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.legacy.vocab.Vocab object at 0x7f54f59f6bd0>>, {'<unk>': 0, '<pad>': 1, '<sos>': 2, '<eos>': 3, 'great': 4, 'good': 5, 'like': 6, 'love': 7, 'taste': 8, 'product': 9, 'coffee': 10, 'flavor': 11, 'one': 12, 'tea': 13, 'would': 14, 'best': 15, 'price': 16, 'really': 17, 'get': 18, 'buy': 19, 'amazon': 20, 'much': 21, 'find': 22, 'time': 23, 'use': 24, 'better': 25, 'little': 26, 'tried': 27, 'food': 28, 'well': 29, 'eat': 30, 'dog': 31, 'make': 32, 'delicious': 33, 'chocolate': 34, 'loves': 35, 'also': 36, 'try': 37, 'bought': 38, 'order': 39, 'favorite': 40, 'even': 41, 'recommend': 42, 'tastes': 43, 'can': 44, 'not': 45, 'sweet': 
especially': 238, 'available': 239, 'half': 240, 'kind': 241, 'house': 242, 'bread': 243, 'cats': 244, 'diet': 245, 'case': 246, 'save': 247, 'us': 248, 'trying': 249, 'teeth': 250, 'nothing': 251, 'come': 252, 'days': 253, 'recommended': 254, 'variety': 255, 'amazing': 256, 'spicy': 257, 'usually': 258, 'seems': 259, 'per': 260, 'added': 261, 'fat': 262, 'others': 263, 'thank': 264, 'awesome': 265, 'company': 266, 'everyone': 267, 'packaging': 268, 'rich': 269, 'black': 270, 'boxes': 271, 'everything': 272, 'problem': 273, 'oz': 274, 'daughter': 275, 'large': 276, 'honey': 277, 'value': 278, 'fine': 279, 'li ...
# None

# %%
print(train_data[5].__dict__.keys())
print(train_data[5].__dict__.values())

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
BATCH_SIZE = 32

train_iterator, valid_iterator = BucketIterator.splits(
    (train_data, val_data), 
    batch_size = BATCH_SIZE,
    sort_key=lambda x: len(x.summary),
    sort_within_batch=True,
    device = device)

# %%
count = 0
max_len_eng = []
max_len_ger = []
for data in train_data:
  max_len_ger.append(len(data.text))
  max_len_eng.append(len(data.summary))
  if count < 10 :
    print("German - ",*data.text, " Length - ", len(data.text))
    print("English - ",*data.summary, " Length - ", len(data.summary))
    print()
  count += 1

print("Maximum Length of English sentence {} and German sentence {} in the dataset".format(max(max_len_eng),max(max_len_ger)))
print("Minimum Length of English sentence {} and German sentence {} in the dataset".format(min(max_len_eng),min(max_len_ger)))

# %%
count = 0
for data in train_iterator:
  if count < 1 :
    print("Shapes", data.text.shape, data.summary.shape)
    print()
    print("German - ",*data.text, " Length - ", len(data.text))
    print()
    print("English - ",*data.summary, " Length - ", len(data.summary))
    temp_ger = data.text
    temp_eng = data.summary
    count += 1

# %%
import pandas as pd

df_eng_idx = pd.DataFrame(data = temp_eng_idx, columns = [str("S_")+str(x) for x in np.arange(1, 33)])
df_eng_idx.index.name = 'Time Steps'
df_eng_idx.index = df_eng_idx.index + 1 
# df_eng_idx.to_csv('/content/idx.csv')
df_eng_idx

# %%
df_eng_word = pd.DataFrame(columns = [str("S_")+str(x) for x in np.arange(1, 33)])
df_eng_word = df_eng_idx.replace(idx_2_word)
# df_eng_word.to_csv('/content/Words.csv')
df_eng_word

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        self.dropout = nn.Dropout(dropout)
    def forward(self, src):
        embedded = self.dropout(self.embedding(src))
        outputs, (hidden, cell) = self.rnn(embedded)
        return hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hid_dim, n_layers, dropout):
        super().__init__()
        
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.LSTM(emb_dim, hid_dim, n_layers, dropout = dropout)
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, cell):
        input = input.unsqueeze(0)
        #input = [1, batch size]
        embedded = self.dropout(self.embedding(input))
        #embedded = [1, batch size, emb dim]
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        prediction = self.fc_out(output.squeeze(0))
        #prediction = [batch size, output dim]
        
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
        assert encoder.hid_dim == decoder.hid_dim, \
            "Hidden dimensions of encoder and decoder must be equal!"
        assert encoder.n_layers == decoder.n_layers, \
            "Encoder and decoder must have equal number of layers!"
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        
        batch_size = trg.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        
        #last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src)
        
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden and previous cell states
            #receive output tensor (predictions) and new hidden and cell states
            output, hidden, cell = self.decoder(input, hidden, cell)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1
        
        return outputs

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 100
DEC_EMB_DIM = 100
HID_DIM = 512
N_LAYERS = 2
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

enc = Encoder(INPUT_DIM, ENC_EMB_DIM, HID_DIM, N_LAYERS, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, HID_DIM, N_LAYERS, DEC_DROPOUT)

model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
      nn.init.uniform_(param.data, -0.5, 0.5)
        # nn.init.uniform_(param.data, 0.0,1.0)
        
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(8325, 100)
#     (rnn): LSTM(100, 512, num_layers=2, dropout=0.5)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(2683, 100)
#     (rnn): LSTM(100, 512, num_layers=2, dropout=0.5)
#     (fc_out): Linear(in_features=512, out_features=2683, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 9,194,619 trainable parameters

# %%
optimizer = optim.Adam(model.parameters(),lr=0.00001)

# %%
# TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
criterion = nn.CrossEntropyLoss()

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.text
        trg = batch.summary
        
        optimizer.zero_grad()
        
        output = model(src, trg)
        
        #trg = [trg len, batch size]
        #output = [trg len, batch size, output dim]
        
        output_dim = output.shape[-1]
        
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.text
            trg = batch.summary

            output = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg len, batch size]
            #output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]
            
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            #trg = [(trg len - 1) * batch size]
            #output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)
            
            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
def translate_sentence(model, sentence, src, trg, device, max_length=50):

  # print(sentence)
  # Load german tokenizer
  spacy_en = spacy.load("en")

  # Create tokens using spacy and everything in lower case (which is what our vocab is)
  if type(sentence) == str:
      tokens = [token.text.lower() for token in spacy_en(sentence)]
  else:
      tokens = [token.lower() for token in sentence]

  # print(tokens)

  # sys.exit()
  # Add <SOS> and <EOS> in beginning and end respectively
  tokens.insert(0, src.init_token)
  tokens.append(src.eos_token)

  # Go through each german token and convert to an index
  text_to_indices = [src.vocab.stoi[token] for token in tokens]

  # Convert to Tensor
  sentence_tensor = torch.LongTensor(text_to_indices).unsqueeze(1).to(device)

  # Build encoder hidden, cell state
  with torch.no_grad():
      hidden, cell = model.encoder(sentence_tensor)

  outputs = [trg.vocab.stoi["<sos>"]]

  for _ in range(max_length):
      previous_word = torch.LongTensor([outputs[-1]]).to(device)

      with torch.no_grad():
          output, hidden, cell = model.decoder(previous_word, hidden, cell)
          best_guess = output.argmax(1).item()

      outputs.append(best_guess)

      # Model predicts it's the end of the sentence
      if output.argmax(1).item() == trg.vocab.stoi["<eos>"] or output.argmax(1).item() == trg.vocab.stoi["eos"]:
          break

  translated_sentence = [trg.vocab.itos[idx] for idx in outputs]

  # remove start token
  return translated_sentence[1:]

# %%
sentance = "yummy product convenient love warm mine microwave seconds dive"

# %%
N_EPOCHS = 50
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):

    print(translate_sentence(model,sentance, SRC, TRG, device, max_length=50) )

    start_time = time.time()
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'modelv1.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')

# %%
model.load_state_dict(torch.load('modelv1.pt'))
test_loss = evaluate(model, valid_iterator, criterion)
print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 10.766 | Test PPL: 47384.592 |

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/mydata/test.csv")

# %%
n=30
for i in range(n):
  index = round(random.random()*df.shape[0])
  print("Review : " + df["text"][index])
  print("original : ", df["summary"][index])
  print(translate_sentence(model, df["text"][index], SRC, TRG, device, max_length=50) )
  print("*"*1000)

# %%
# !git clone https://github.com/pytorch/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 2876, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 2876 (delta 3), reused 6 (delta 1), pack-reused 2863
# Receiving objects: 100% (2876/2876), 39.18 MiB | 17.70 MiB/s, done.
# Resolving deltas: 100% (1440/1440), done.

# %%
# !cd /content/word_language_model/

# %%
# !python /content/word_language_model/main.py --cuda --data /content/word_language_model/data/wikitext-2 --epochs 15
# Out:
# | epoch   1 |   200/ 2983 batches | lr 20.00 | ms/batch 47.59 | loss  7.63 | ppl  2068.24
# | epoch   1 |   400/ 2983 batches | lr 20.00 | ms/batch 45.26 | loss  6.86 | ppl   953.24
# | epoch   1 |   600/ 2983 batches | lr 20.00 | ms/batch 45.22 | loss  6.50 | ppl   663.25
# | epoch   1 |   800/ 2983 batches | lr 20.00 | ms/batch 45.10 | loss  6.30 | ppl   544.83
# | epoch   1 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  6.16 | ppl   471.85
# | epoch   1 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.04 | loss  6.07 | ppl   432.85
# | epoch   1 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  5.96 | ppl   387.37
# | epoch   1 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  5.96 | ppl   388.76
# | epoch   1 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.17 | loss  5.82 | ppl   336.07
# | epoch   1 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.22 | loss  5.80 | ppl   330.01
# | epoch   1 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.26 | loss  5.68 | ppl   294.24
# | epoch   1 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  5.69 | ppl   294.79
# | epoch   1 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.22 | loss  5.67 | ppl   288.88
# | epoch   1 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.19 | loss  5.55 | ppl   257.54
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 140.33s | valid loss  5.51 | valid ppl   246.62
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2983 batches | lr 20.00 | ms/batch 45.27 | loss  5.55 | ppl   256.76
# | epoch   2 |   400/ 2983 batches | lr 20.00 | ms/batch 45.12 | loss  5.53 | ppl   252.49
# | epoch   2 |   600/ 2983 batches | lr 20.00 | ms/batch 45.25 | loss  5.36 | ppl   212.61
# | epoch   2 |   800/ 2983 batches | lr 20.00 | ms/batch 45.10 | loss  5.38 | ppl   216.30
# | epoch   2 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.24 | loss  5.35 | ppl   210.95
# | epoch   2 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.13 | loss  5.34 | ppl   207.89
# | epoch   2 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.24 | loss  5.33 | ppl   206.59
# | epoch   2 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  5.40 | ppl   220.46
# | epoch   2 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.16 | loss  5.26 | ppl   192.85
# | epoch   2 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.10 | loss  5.28 | ppl   196.06
# | epoch   2 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.15 | loss  5.18 | ppl   177.93
# | epoch   2 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.13 | loss  5.21 | ppl   183.47
# | epoch   2 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.08 | loss  5.22 | ppl   185.64
# | epoch   2 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.08 | loss  5.13 | ppl   169.13
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 139.76s | valid loss  5.27 | valid ppl   194.56
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2983 batches | lr 20.00 | ms/batch 45.35 | loss  5.19 | ppl   179.85
# | epoch   3 |   400/ 2983 batches | lr 20.00 | ms/batch 45.11 | loss  5.20 | ppl   180.84
# | epoch   3 |   600/ 2983 batches | lr 20.00 | ms/batch 45.14 | loss  5.02 | ppl   151.71
# | epoch   3 |   800/ 2983 batches | lr 20.00 | ms/batch 45.16 | loss  5.07 | ppl   159.53
# | epoch   3 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.15 | loss  5.06 | ppl   156.86
# | epoch   3 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.19 | loss  5.06 | ppl   157.00
# | epoch   3 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.07 | loss  5.08 | ppl   160.40
# | epoch   3 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.12 | loss  5.15 | ppl   172.80
# | epoch   3 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.09 | loss  5.02 | ppl   151.64
# | epoch   3 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.05 | loss  5.05 | ppl   155.81
# | epoch   3 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.26 | loss  4.95 | ppl   141.84
# | epoch   3 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.23 | loss  4.99 | ppl   146.94
# | epoch   3 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.11 | loss  5.01 | ppl   149.78
# | epoch   3 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  4.93 | ppl   138.77
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 139.79s | valid loss  5.18 | valid ppl   177.34
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/ 2983 batches | lr 20.00 | ms/batch 45.36 | loss  5.00 | ppl   148.63
# | epoch   4 |   400/ 2983 batches | lr 20.00 | ms/batch 45.20 | loss  5.02 | ppl   151.37
# | epoch   4 |   600/ 2983 batches | lr 20.00 | ms/batch 45.18 | loss  4.84 | ppl   125.98
# | epoch   4 |   800/ 2983 batches | lr 20.00 | ms/batch 45.12 | loss  4.89 | ppl   132.90
# | epoch   4 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.28 | loss  4.89 | ppl   132.44
# | epoch   4 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.22 | loss  4.90 | ppl   134.52
# | epoch   4 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.11 | loss  4.93 | ppl   138.35
# | epoch   4 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.23 | loss  5.00 | ppl   148.70
# | epoch   4 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.23 | loss  4.88 | ppl   130.99
# | epoch   4 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.31 | loss  4.91 | ppl   136.01
# | epoch   4 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.32 | loss  4.81 | ppl   123.05
# | epoch   4 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.42 | loss  4.85 | ppl   128.19
# | epoch   4 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.23 | loss  4.87 | ppl   130.79
# | epoch   4 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.45 | loss  4.80 | ppl   121.65
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 140.12s | valid loss  5.11 | valid ppl   166.09
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/ 2983 batches | lr 20.00 | ms/batch 45.73 | loss  4.87 | ppl   130.77
# | epoch   5 |   400/ 2983 batches | lr 20.00 | ms/batch 45.19 | loss  4.89 | ppl   133.58
# | epoch   5 |   600/ 2983 batches | lr 20.00 | ms/batch 45.46 | loss  4.71 | ppl   111.48
# | epoch   5 |   800/ 2983 batches | lr 20.00 | ms/batch 45.41 | loss  4.77 | ppl   117.91
# | epoch   5 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.44 | loss  4.78 | ppl   118.59
# | epoch   5 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.50 | loss  4.79 | ppl   120.32
# | epoch   5 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.42 | loss  4.82 | ppl   124.17
# | epoch   5 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.48 | loss  4.89 | ppl   133.07
# | epoch   5 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.47 | loss  4.78 | ppl   118.64
# | epoch   5 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.41 | loss  4.81 | ppl   122.82
# | epoch   5 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.57 | loss  4.71 | ppl   110.76
# | epoch   5 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.51 | loss  4.75 | ppl   115.97
# | epoch   5 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.51 | loss  4.77 | ppl   118.36
# | epoch   5 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.49 | loss  4.70 | ppl   110.47
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 140.73s | valid loss  5.04 | valid ppl   154.28
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/ 2983 batches | lr 20.00 | ms/batch 45.85 | loss  4.78 | ppl   118.53
# | epoch   6 |   400/ 2983 batches | lr 20.00 | ms/batch 45.56 | loss  4.79 | ppl   120.71
# | epoch   6 |   600/ 2983 batches | lr 20.00 | ms/batch 45.73 | loss  4.63 | ppl   102.10
# | epoch   6 |   800/ 2983 batches | lr 20.00 | ms/batch 45.70 | loss  4.68 | ppl   107.73
# | epoch   6 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.77 | loss  4.69 | ppl   108.84
# | epoch   6 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.70 | loss  4.71 | ppl   110.69
# | epoch   6 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.73 | loss  4.74 | ppl   113.97
# | epoch   6 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.70 | loss  4.81 | ppl   122.94
# | epoch   6 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.80 | loss  4.69 | ppl   109.09
# | epoch   6 |  2000/ 2983 batches | lr 20.00 | ms/batch 45.61 | loss  4.73 | ppl   113.32
# | epoch   6 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.80 | loss  4.62 | ppl   101.98
# | epoch   6 |  2400/ 2983 batches | lr 20.00 | ms/batch 46.07 | loss  4.67 | ppl   107.22
# | epoch   6 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.79 | loss  4.70 | ppl   109.98
# | epoch   6 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.78 | loss  4.63 | ppl   102.95
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 141.56s | valid loss  5.01 | valid ppl   150.32
# -----------------------------------------------------------------------------------------
# | epoch   7 |   200/ 2983 batches | lr 20.00 | ms/batch 46.05 | loss  4.69 | ppl   109.35
# | epoch   7 |   400/ 2983 batches | lr 20.00 | ms/batch 45.74 | loss  4.72 | ppl   112.49
# | epoch   7 |   600/ 2983 batches | lr 20.00 | ms/batch 45.65 | loss  4.55 | ppl    94.39
# | epoch   7 |   800/ 2983 batches | lr 20.00 | ms/batch 45.95 | loss  4.60 | ppl    99.82
# | epoch   7 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.98 | loss  4.62 | ppl   101.39
# | epoch   7 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.88 | loss  4.64 | ppl   103.05
# | epoch   7 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.83 | loss  4.67 | ppl   106.66
# | epoch   7 |  1600/ 2983 batches | lr 20.00 | ms/batch 45.89 | loss  4.74 | ppl   114.66
# | epoch   7 |  1800/ 2983 batches | lr 20.00 | ms/batch 46.03 | loss  4.64 | ppl   103.22
# | epoch   7 |  2000/ 2983 batches | lr 20.00 | ms/batch 46.13 | loss  4.67 | ppl   106.24
# | epoch   7 |  2200/ 2983 batches | lr 20.00 | ms/batch 46.28 | loss  4.56 | ppl    95.96
# | epoch   7 |  2400/ 2983 batches | lr 20.00 | ms/batch 46.07 | loss  4.61 | ppl   100.59
# | epoch   7 |  2600/ 2983 batches | lr 20.00 | ms/batch 46.07 | loss  4.64 | ppl   103.39
# | epoch   7 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.80 | loss  4.57 | ppl    96.71
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 142.10s | valid loss  5.00 | valid ppl   149.10
# -----------------------------------------------------------------------------------------
# | epoch   8 |   200/ 2983 batches | lr 20.00 | ms/batch 46.08 | loss  4.64 | ppl   103.05
# | epoch   8 |   400/ 2983 batches | lr 20.00 | ms/batch 45.73 | loss  4.65 | ppl   104.76
# | epoch   8 |   600/ 2983 batches | lr 20.00 | ms/batch 46.07 | loss  4.49 | ppl    89.04
# | epoch   8 |   800/ 2983 batches | lr 20.00 | ms/batch 46.24 | loss  4.55 | ppl    94.58
# | epoch   8 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.88 | loss  4.56 | ppl    95.66
# | epoch   8 |  1200/ 2983 batches | lr 20.00 | ms/batch 46.21 | loss  4.58 | ppl    97.09
# | epoch   8 |  1400/ 2983 batches | lr 20.00 | ms/batch 46.03 | loss  4.61 | ppl   100.23
# | epoch   8 |  1600/ 2983 batches | lr 20.00 | ms/batch 46.08 | loss  4.69 | ppl   108.70
# | epoch   8 |  1800/ 2983 batches | lr 20.00 | ms/batch 45.62 | loss  4.58 | ppl    97.45
# | epoch   8 |  2000/ 2983 batches | lr 20.00 | ms/batch 46.37 | loss  4.61 | ppl   100.74
# | epoch   8 |  2200/ 2983 batches | lr 20.00 | ms/batch 45.91 | loss  4.50 | ppl    90.27
# | epoch   8 |  2400/ 2983 batches | lr 20.00 | ms/batch 45.65 | loss  4.56 | ppl    95.37
# | epoch   8 |  2600/ 2983 batches | lr 20.00 | ms/batch 45.91 | loss  4.59 | ppl    98.20
# | epoch   8 |  2800/ 2983 batches | lr 20.00 | ms/batch 45.56 | loss  4.53 | ppl    92.42
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 142.19s | valid loss  4.99 | valid ppl   146.60
# -----------------------------------------------------------------------------------------
# | epoch   9 |   200/ 2983 batches | lr 20.00 | ms/batch 46.51 | loss  4.58 | ppl    97.78
# | epoch   9 |   400/ 2983 batches | lr 20.00 | ms/batch 45.90 | loss  4.60 | ppl    99.98
# | epoch   9 |   600/ 2983 batches | lr 20.00 | ms/batch 45.56 | loss  4.44 | ppl    84.36
# | epoch   9 |   800/ 2983 batches | lr 20.00 | ms/batch 45.63 | loss  4.49 | ppl    89.51
# | epoch   9 |  1000/ 2983 batches | lr 20.00 | ms/batch 45.65 | loss  4.51 | ppl    91.02
# | epoch   9 |  1200/ 2983 batches | lr 20.00 | ms/batch 45.64 | loss  4.53 | ppl    92.61
# | epoch   9 |  1400/ 2983 batches | lr 20.00 | ms/batch 45.84 | loss  4.57 | ppl    96.37
# | epoch   9 |  1600/ 2983 batches | lr 20.00 | ms/batch 46.24 | loss  4.64 | ppl   103.63
# | epoch   9 |  1800/ 2983 batches | lr 20.00 | ms/batch 46.29 | loss  4.53 | ppl    93.13
# | epoch   9 |  2000/ 2983 batches | lr 20.00 | ms/batch 46.33 | loss  4.57 | ppl    96.15
# | epoch   9 |  2200/ 2983 batches | lr 20.00 | ms/batch 46.32 | loss  4.45 | ppl    86.05
# | epoch   9 |  2400/ 2983 batches | lr 20.00 | ms/batch 46.23 | loss  4.51 | ppl    90.95
# | epoch   9 |  2600/ 2983 batches | lr 20.00 | ms/batch 46.28 | loss  4.54 | ppl    93.92
# | epoch   9 |  2800/ 2983 batches | lr 20.00 | ms/batch 46.29 | loss  4.48 | ppl    88.09
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 142.46s | valid loss  4.99 | valid ppl   146.93
# -----------------------------------------------------------------------------------------
# | epoch  10 |   200/ 2983 batches | lr 5.00 | ms/batch 45.87 | loss  4.58 | ppl    97.79
# | epoch  10 |   400/ 2983 batches | lr 5.00 | ms/batch 46.07 | loss  4.57 | ppl    96.37
# | epoch  10 |   600/ 2983 batches | lr 5.00 | ms/batch 46.13 | loss  4.38 | ppl    80.23
# | epoch  10 |   800/ 2983 batches | lr 5.00 | ms/batch 45.63 | loss  4.45 | ppl    85.26
# | epoch  10 |  1000/ 2983 batches | lr 5.00 | ms/batch 45.68 | loss  4.43 | ppl    83.72
# | epoch  10 |  1200/ 2983 batches | lr 5.00 | ms/batch 46.17 | loss  4.42 | ppl    83.29
# | epoch  10 |  1400/ 2983 batches | lr 5.00 | ms/batch 45.84 | loss  4.44 | ppl    84.61
# | epoch  10 |  1600/ 2983 batches | lr 5.00 | ms/batch 45.71 | loss  4.49 | ppl    89.57
# | epoch  10 |  1800/ 2983 batches | lr 5.00 | ms/batch 46.11 | loss  4.37 | ppl    78.72
# | epoch  10 |  2000/ 2983 batches | lr 5.00 | ms/batch 46.24 | loss  4.41 | ppl    82.08
# | epoch  10 |  2200/ 2983 batches | lr 5.00 | ms/batch 45.66 | loss  4.27 | ppl    71.18
# | epoch  10 |  2400/ 2983 batches | lr 5.00 | ms/batch 45.67 | loss  4.30 | ppl    73.57
# | epoch  10 |  2600/ 2983 batches | lr 5.00 | ms/batch 45.70 | loss  4.31 | ppl    74.37
# | epoch  10 |  2800/ 2983 batches | lr 5.00 | ms/batch 45.67 | loss  4.24 | ppl    69.48
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 141.84s | valid loss  4.84 | valid ppl   126.60
# -----------------------------------------------------------------------------------------
# | epoch  11 |   200/ 2983 batches | lr 5.00 | ms/batch 45.87 | loss  4.44 | ppl    84.53
# | epoch  11 |   400/ 2983 batches | lr 5.00 | ms/batch 45.65 | loss  4.44 | ppl    85.17
# | epoch  11 |   600/ 2983 batches | lr 5.00 | ms/batch 45.59 | loss  4.27 | ppl    71.80
# | epoch  11 |   800/ 2983 batches | lr 5.00 | ms/batch 45.66 | loss  4.33 | ppl    75.96
# | epoch  11 |  1000/ 2983 batches | lr 5.00 | ms/batch 45.64 | loss  4.33 | ppl    75.90
# | epoch  11 |  1200/ 2983 batches | lr 5.00 | ms/batch 45.62 | loss  4.34 | ppl    76.80
# | epoch  11 |  1400/ 2983 batches | lr 5.00 | ms/batch 45.67 | loss  4.36 | ppl    78.19
# | epoch  11 |  1600/ 2983 batches | lr 5.00 | ms/batch 45.62 | loss  4.43 | ppl    83.79
# | epoch  11 |  1800/ 2983 batches | lr 5.00 | ms/batch 45.57 | loss  4.30 | ppl    74.07
# | epoch  11 |  2000/ 2983 batches | lr 5.00 | ms/batch 45.59 | loss  4.36 | ppl    78.01
# | epoch  11 |  2200/ 2983 batches | lr 5.00 | ms/batch 45.64 | loss  4.22 | ppl    67.81
# | epoch  11 |  2400/ 2983 batches | lr 5.00 | ms/batch 45.59 | loss  4.26 | ppl    70.94
# | epoch  11 |  2600/ 2983 batches | lr 5.00 | ms/batch 45.68 | loss  4.28 | ppl    72.59
# | epoch  11 |  2800/ 2983 batches | lr 5.00 | ms/batch 45.61 | loss  4.21 | ppl    67.66
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 141.19s | valid loss  4.83 | valid ppl   125.28
# -----------------------------------------------------------------------------------------
# | epoch  12 |   200/ 2983 batches | lr 5.00 | ms/batch 45.87 | loss  4.39 | ppl    80.60
# | epoch  12 |   400/ 2983 batches | lr 5.00 | ms/batch 45.66 | loss  4.39 | ppl    80.93
# | epoch  12 |   600/ 2983 batches | lr 5.00 | ms/batch 45.65 | loss  4.22 | ppl    67.83
# | epoch  12 |   800/ 2983 batches | lr 5.00 | ms/batch 45.62 | loss  4.29 | ppl    72.66
# | epoch  12 |  1000/ 2983 batches | lr 5.00 | ms/batch 45.51 | loss  4.29 | ppl    72.88
# | epoch  12 |  1200/ 2983 batches | lr 5.00 | ms/batch 45.69 | loss  4.30 | ppl    73.69
# | epoch  12 |  1400/ 2983 batches | lr 5.00 | ms/batch 45.63 | loss  4.32 | ppl    75.56
# | epoch  12 |  1600/ 2983 batches | lr 5.00 | ms/batch 45.63 | loss  4.39 | ppl    80.53
# | epoch  12 |  1800/ 2983 batches | lr 5.00 | ms/batch 45.56 | loss  4.27 | ppl    71.80
# | epoch  12 |  2000/ 2983 batches | lr 5.00 | ms/batch 45.71 | loss  4.32 | ppl    75.47
# | epoch  12 |  2200/ 2983 batches | lr 5.00 | ms/batch 45.65 | loss  4.19 | ppl    65.98
# | epoch  12 |  2400/ 2983 batches | lr 5.00 | ms/batch 45.68 | loss  4.23 | ppl    68.84
# | epoch  12 |  2600/ 2983 batches | lr 5.00 | ms/batch 45.64 | loss  4.26 | ppl    70.65
# | epoch  12 |  2800/ 2983 batches | lr 5.00 | ms/batch 45.63 | loss  4.19 | ppl    66.26
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 141.38s | valid loss  4.82 | valid ppl   123.67
# -----------------------------------------------------------------------------------------
# | epoch  13 |   200/ 2983 batches | lr 5.00 | ms/batch 46.71 | loss  4.35 | ppl    77.20
# | epoch  13 |   400/ 2983 batches | lr 5.00 | ms/batch 46.44 | loss  4.35 | ppl    77.81
# | epoch  13 |   600/ 2983 batches | lr 5.00 | ms/batch 46.48 | loss  4.18 | ppl    65.58
# | epoch  13 |   800/ 2983 batches | lr 5.00 | ms/batch 46.41 | loss  4.25 | ppl    69.77
# | epoch  13 |  1000/ 2983 batches | lr 5.00 | ms/batch 46.46 | loss  4.25 | ppl    70.46
# | epoch  13 |  1200/ 2983 batches | lr 5.00 | ms/batch 46.30 | loss  4.27 | ppl    71.37
# | epoch  13 |  1400/ 2983 batches | lr 5.00 | ms/batch 46.35 | loss  4.29 | ppl    72.87
# | epoch  13 |  1600/ 2983 batches | lr 5.00 | ms/batch 46.27 | loss  4.36 | ppl    78.13
# | epoch  13 |  1800/ 2983 batches | lr 5.00 | ms/batch 46.32 | loss  4.25 | ppl    70.07
# | epoch  13 |  2000/ 2983 batches | lr 5.00 | ms/batch 46.32 | loss  4.30 | ppl    73.64
# | epoch  13 |  2200/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.16 | ppl    64.22
# | epoch  13 |  2400/ 2983 batches | lr 5.00 | ms/batch 46.30 | loss  4.21 | ppl    67.45
# | epoch  13 |  2600/ 2983 batches | lr 5.00 | ms/batch 46.31 | loss  4.24 | ppl    69.22
# | epoch  13 |  2800/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.17 | ppl    64.86
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 143.32s | valid loss  4.81 | valid ppl   123.26
# -----------------------------------------------------------------------------------------
# | epoch  14 |   200/ 2983 batches | lr 5.00 | ms/batch 46.43 | loss  4.32 | ppl    74.84
# | epoch  14 |   400/ 2983 batches | lr 5.00 | ms/batch 46.22 | loss  4.33 | ppl    75.71
# | epoch  14 |   600/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.15 | ppl    63.65
# | epoch  14 |   800/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.22 | ppl    67.76
# | epoch  14 |  1000/ 2983 batches | lr 5.00 | ms/batch 46.28 | loss  4.23 | ppl    68.41
# | epoch  14 |  1200/ 2983 batches | lr 5.00 | ms/batch 46.29 | loss  4.24 | ppl    69.53
# | epoch  14 |  1400/ 2983 batches | lr 5.00 | ms/batch 46.20 | loss  4.27 | ppl    71.18
# | epoch  14 |  1600/ 2983 batches | lr 5.00 | ms/batch 46.30 | loss  4.33 | ppl    76.30
# | epoch  14 |  1800/ 2983 batches | lr 5.00 | ms/batch 46.30 | loss  4.23 | ppl    68.72
# | epoch  14 |  2000/ 2983 batches | lr 5.00 | ms/batch 46.25 | loss  4.27 | ppl    71.66
# | epoch  14 |  2200/ 2983 batches | lr 5.00 | ms/batch 46.31 | loss  4.14 | ppl    62.81
# | epoch  14 |  2400/ 2983 batches | lr 5.00 | ms/batch 46.34 | loss  4.19 | ppl    65.84
# | epoch  14 |  2600/ 2983 batches | lr 5.00 | ms/batch 46.21 | loss  4.22 | ppl    67.76
# | epoch  14 |  2800/ 2983 batches | lr 5.00 | ms/batch 46.24 | loss  4.16 | ppl    63.83
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 143.09s | valid loss  4.81 | valid ppl   122.68
# -----------------------------------------------------------------------------------------
# | epoch  15 |   200/ 2983 batches | lr 5.00 | ms/batch 46.39 | loss  4.29 | ppl    72.65
# | epoch  15 |   400/ 2983 batches | lr 5.00 | ms/batch 46.34 | loss  4.29 | ppl    73.32
# | epoch  15 |   600/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.12 | ppl    61.82
# | epoch  15 |   800/ 2983 batches | lr 5.00 | ms/batch 46.28 | loss  4.19 | ppl    66.06
# | epoch  15 |  1000/ 2983 batches | lr 5.00 | ms/batch 46.24 | loss  4.21 | ppl    67.11
# | epoch  15 |  1200/ 2983 batches | lr 5.00 | ms/batch 46.29 | loss  4.22 | ppl    67.98
# | epoch  15 |  1400/ 2983 batches | lr 5.00 | ms/batch 46.23 | loss  4.25 | ppl    69.88
# | epoch  15 |  1600/ 2983 batches | lr 5.00 | ms/batch 46.30 | loss  4.31 | ppl    74.72
# | epoch  15 |  1800/ 2983 batches | lr 5.00 | ms/batch 46.27 | loss  4.21 | ppl    67.27
# | epoch  15 |  2000/ 2983 batches | lr 5.00 | ms/batch 46.33 | loss  4.26 | ppl    70.46
# | epoch  15 |  2200/ 2983 batches | lr 5.00 | ms/batch 46.25 | loss  4.12 | ppl    61.55
# | epoch  15 |  2400/ 2983 batches | lr 5.00 | ms/batch 46.28 | loss  4.17 | ppl    64.62
# | epoch  15 |  2600/ 2983 batches | lr 5.00 | ms/batch 46.37 | loss  4.20 | ppl    66.62
# | epoch  15 |  2800/ 2983 batches | lr 5.00 | ms/batch 46.35 | loss  4.14 | ppl    63.06
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 143.16s | valid loss  4.81 | valid ppl   122.85
# -----------------------------------------------------------------------------------------
# =========================================================================================
# | End of training | test loss  4.75 | test ppl   115.21
# =========================================================================================

# %%
# !python /content/word_language_model/generate.py --cuda --data /content/word_language_model/data/wikitext-2
# Out:
# /content/word_language_model/data/wikitext-2/train.txt
# /content/word_language_model/data/wikitext-2/valid.txt
# /content/word_language_model/data/wikitext-2/test.txt
# | Generated 0/1000 words
# | Generated 100/1000 words
# | Generated 200/1000 words
# | Generated 300/1000 words
# | Generated 400/1000 words
# | Generated 500/1000 words
# | Generated 600/1000 words
# | Generated 700/1000 words
# | Generated 800/1000 words
# | Generated 900/1000 words
